# %% [markdown]
# <a href="https://colab.research.google.com/github/uma-ram/Mlops_DisasterTweetsClassification/blob/main/Execute_train_bert.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/uma-ram/Mlops_DisasterTweetsClassification.git

# %cd Mlops_DisasterTweetsClassification
# Out:
# Cloning into 'Mlops_DisasterTweetsClassification'...
# remote: Enumerating objects: 543, done.
# remote: Counting objects: 100% (543/543), done.
# remote: Compressing objects: 100% (224/224), done.
# remote: Total 543 (delta 108), reused 518 (delta 89), pack-reused 0 (from 0)
# Receiving objects: 100% (543/543), 6.03 MiB | 15.25 MiB/s, done.
# Resolving deltas: 100% (108/108), done.
# /content/Mlops_DisasterTweetsClassification

# %%
# Upgrade pip and install all dependencies
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.5/123.5 kB 5.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 6.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.7/53.7 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 72.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.0/261.0 kB 24.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.7/24.7 MB 101.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 92.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 117.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 8.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 106.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 95.3 MB/s eta 0:00:00
# ...

# %%
# Run the training script
# !PYTHONPATH=. python scripts/train_bert.py

# %%
# Clean install of compatible library versions
# !pip uninstall -y transformers accelerate peft
# !pip install transformers==4.36.2 accelerate==0.25.0 peft==0.7.1

# %%
# !pip install -q evaluate

# %%
# !pip install mlflow pyngrok --quiet

# %%
# !ngrok config add-authtoken 30B0V8IWNroZjkDJYDqVqhqCkIm_26kjfPLmBnsrxfZ4LWAjT
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
from pyngrok import conf
conf.get_default().auth_token = "30B0V8IWNroZjkDJYDqVqhqCkIm_26kjfPLmBnsrxfZ4LWAjT"  # replace with yours

# %%
# Replace 'YOUR_NGROK_AUTHTOKEN' with your actual ngrok authtoken
# You can find your authtoken on your ngrok dashboard: https://dashboard.ngrok.com/get-started/your-authtoken
ngrok.set_auth_token("30B0V8IWNroZjkDJYDqVqhqCkIm_26kjfPLmBnsrxfZ4LWAjT")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-5-960809856.py in <cell line: 0>()
#       1 # Replace 'YOUR_NGROK_AUTHTOKEN' with your actual ngrok authtoken
#       2 # You can find your authtoken on your ngrok dashboard: https://dashboard.ngrok.com/get-started/your-authtoken
# ----> 3 ngrok.set_auth_token("30B0V8IWNroZjkDJYDqVqhqCkIm_26kjfPLmBnsrxfZ4LWAjT")
#
# NameError: name 'ngrok' is not defined

# %%
import mlflow
from pyngrok import ngrok

# Start MLflow UI (port 5000)
get_ipython().system_raw("mlflow ui --backend-store-uri file:./mlruns --port 5000 &")

# Open ngrok tunnel to the MLflow UI
mlflow_url = ngrok.connect(5000)
print(f"🔗 Open MLflow UI at: {mlflow_url}")
# Out:
# 🔗 Open MLflow UI at: NgrokTunnel: "https://893b4675f22c.ngrok-free.app" -> "http://localhost:5000"

# %%
# !pip install --upgrade accelerate

# %%
# !pip install "transformers==4.41.0" "peft==0.10.0" "accelerate==0.31.0"

# %%
# !PYTHONPATH=. python scripts/train_bert.py
# Out:
# 2025-07-22 19:52:17.834977: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1753213937.856576    7465 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1753213937.863138    7465 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-07-22 19:52:17.885725: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !git pull origin main
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 526 bytes | 526.00 KiB/s, done.
# From https://github.com/uma-ram/Mlops_DisasterTweetsClassification
#  * branch            main       -> FETCH_HEAD
#    7addaf9..46f754c  main       -> origin/main
# Updating 7addaf9..46f754c
# Fast-forward
#  scripts/train_bert.py | 10 +++++++++-
#  1 file changed, 9 insertions(+), 1 deletion(-)

# %%
# !PYTHONPATH=. python scripts/train_bert.py
3
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /usr/local/lib/python3.11/dist-packages/transformers/utils/generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /usr/local/lib/python3.11/dist-packages/transformers/utils/generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# 2025-07-21 08:36:45.479897: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# ...
